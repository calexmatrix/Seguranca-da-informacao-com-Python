# %%
import itertools

resultado = itertools.permutations('abc', 3)

for i in resultado:
    print(''.join(i))
# Out:
# abc
# acb
# bac
# bca
# cab
# cba

# %%
import itertools

string = input("String a ser permutada: ")

resultado1 = itertools.permutations(string', len(string))

for i in resultado1:
    print(''.join(i))
# Out:
# String a ser permutada: asd
# str
# sti
# stn
# stg
# srt
# sri
# srn
# srg
# sit
# sir
# sin
# sig
# snt
# snr
# sni
# sng
# sgt
# sgr
# sgi
# sgn
# tsr
# tsi
# tsn
# tsg
# trs
# tri
# trn
# trg
# tis
# tir
# tin
# tig
# tns
# tnr
# tni
# tng
# tgs
# tgr
# tgi
# tgn
# rst
# rsi
# rsn
# rsg
# rts
# rti
# rtn
# rtg
# ris
# rit
# rin
# rig
# rns
# rnt
# rni
# rng
# rgs
# rgt
# rgi
# rgn
# ist
# isr
# isn
# isg
# its
# itr
# itn
# itg
# irs
# irt
# irn
# irg
# ins
# int
# inr
# ing
# igs
# igt
# igr
# ign
# nst
# nsr
# nsi
# nsg
# nts
# ntr
# nti
# ntg
# nrs
# nrt
# nri
# nrg
# nis
# nit
# nir
# nig
# ngs
# ngt
# ngr
# ngi
# gst
# gsr
# gsi
# gsn
# gts
# gtr
# gti
# gtn
# grs
# grt
# gri
# grn
# gis
# git
# gir
# gin
# gns
# gnt
# gnr
# gni
